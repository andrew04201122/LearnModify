# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import networkx as nx
from torch_geometric.data import Data
from torch_geometric.nn import GATConv, GCNConv
from scipy.sparse import coo_matrix
import numpy as np
from torch_geometric.utils import to_networkx
import random
from heapdict import heapdict
from node2vec import Node2Vec
import argparse
import torch.nn.init as init
from utils import *

# %%
graph_embedding_size = 64
edge_sample_number = 100
edge_dict = {}
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# 定义GCN模型
class GCN(torch.nn.Module):
    def __init__(self,num_features):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(num_features, 128)
        self.conv2 = GCNConv(128, graph_embedding_size)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = torch.relu(x)
        x = self.conv2(x, edge_index)
        return x

# 定义GAT模型
class GAT(torch.nn.Module):
    def __init__(self, num_features, num_heads=4, graph_embedding_size=64):
        super(GAT, self).__init__()
        self.gat1 = GATConv(num_features, 512, heads=num_heads, dropout=0.2)
        self.gat2 = GATConv(512 * num_heads, graph_embedding_size, heads=1, concat=False, dropout=0.2)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.gat1(x, edge_index)
        x = F.elu(x)
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.gat2(x, edge_index)
        return x

# 定義用來決定edge是否修改的MLP
class MLP(nn.Module):
    def __init__(self, input_size):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(input_size, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 1)

        init.kaiming_normal_(self.fc1.weight, nonlinearity='relu')
        init.kaiming_normal_(self.fc2.weight, nonlinearity='relu')
        init.kaiming_normal_(self.fc3.weight, nonlinearity='relu')
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = torch.sigmoid(self.fc3(x))
        return x
    
class GCN_edge_modify(nn.Module):
    def __init__(self, num_features, hidden_channels = 512):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(num_features, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        # 最后一层，用于产生最终输出
        self.out = nn.Linear(hidden_channels, 1)

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = self.out(x)
        return torch.sigmoid(x)
    
class MLPClassifier(nn.Module):  #最後用來判定graph的result是否有相同的MVC
    def __init__(self, input_size):
        super(MLPClassifier, self).__init__()
        self.fc1 = nn.Linear(input_size, 512)  # 第一层
        self.fc2 = nn.Linear(512, 128)          # 第二层
        self.fc3 = nn.Linear(128, 1)           # 输出层

        init.kaiming_normal_(self.fc1.weight, nonlinearity='relu')
        init.kaiming_normal_(self.fc2.weight, nonlinearity='relu')
        init.kaiming_normal_(self.fc3.weight, nonlinearity='relu')
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = torch.sigmoid(self.fc3(x))        # 使用sigmoid确保输出在0到1之间
        return x

# %%
class Modify_edge(nn.Module):
    def __init__(self, num_features, graph_embedding_size, epoch = 100, lr = 0.0001, modified_edge = 30, device = 'cuda:0', GraphNumber = 50, Graphsize = 50, num_heads = 8):
        super(Modify_edge, self).__init__()
        self.gat = GAT(num_features=num_features, num_heads=num_heads, graph_embedding_size = graph_embedding_size)  # 根据需要调整头数
        self.mlp = MLP(input_size=3 * graph_embedding_size + 1)
        self.classifier = MLPClassifier(input_size=2 * graph_embedding_size)
        self.modified_edge = modified_edge
        self.epoch = epoch
        self.lr = lr
        self.GraphNumber = GraphNumber
        self.Graphsize = Graphsize
        
        
    def forward(self):
        self.modified_graphs = []
        self.edge_dict = {}
        self.whole_edge_set = set()
        self.dataset = []
        self.init_graph()  ## create self.dataset
        
        original_embeddings = []
        for data in self.dataset:
            data = data.to(device)
            embedding = self.gat(data)
            original_embeddings.append(embedding)
        self.original_graph_embeddings = self.get_graph_embedding(original_embeddings)
        
        for emb, data, graph_emb in zip(original_embeddings, self.dataset, self.original_graph_embeddings):
            modify_edge = self.generate_edge_embeddings(data, emb, graph_emb)
            modify_num = 0
            add_num = 0
            delete_num = 0
            G = to_networkx(data, to_undirected=True)
            for decision in modify_edge:  # decision: (probabilities,(u,v))
                edge = decision[1]
                if (G.has_edge(edge[0], edge[1])):
                    G.remove_edge(edge[0], edge[1])
                    delete_num += 1
                    modify_num += 1
                else:
                    G.add_edge(edge[0], edge[1])
                    modify_num += 1
                    add_num += 1
                    
            # print(f"modify_num: {modify_num}")
            print(f"add_num: {add_num}, delete_num: {delete_num}")
            self.modified_graphs.append(G)
        
        self.modified_dataset = []  #type pyg
        for G in self.modified_graphs:
            # 从 NetworkX 图创建边索引
            edge_index = torch.tensor(list(G.edges)).t().contiguous()
            vec = Node2Vec(G, dimensions=50, walk_length=10, num_walks=10, workers=4, quiet=True)
            InitNodeEmb = vec.fit(window=3, min_count=2, batch_words=4)
            embeddings = InitNodeEmb.wv
            x = torch.tensor(embeddings.vectors, dtype=torch.float32)
            # 使用单位矩阵作为节点特征
            # x = torch.eye(G.number_of_nodes())
            
            # 创建 Data 对象
            data = Data(x=x, edge_index=edge_index)
            self.modified_dataset.append(data)  #networkx
            
        modified_embeddings = []
        for data in self.modified_dataset:
            data = data.to(device)
            embedding = self.gat(data)
            modified_embeddings.append(embedding)  
        self.modified_graph_embeddings = self.get_graph_embedding(modified_embeddings)
        
        cos = nn.CosineSimilarity(dim=1)
        self.cosine_similarities = cos(self.modified_graph_embeddings, self.original_graph_embeddings).mean()
        
        labels = []
        MVC_diff = 0
        for mod_graph, orig_graph in zip(self.modified_graphs, self.dataset):
            mod_mvc = len(self.calculate_MVC(mod_graph))
            orig_mvc = len(self.calculate_MVC(to_networkx(orig_graph, to_undirected=True)))
            # print(f"mod_mvc: {mod_mvc}, ori_mvc: {orig_mvc}")
            MVC_diff = MVC_diff + abs(mod_mvc - orig_mvc) * abs(mod_mvc - orig_mvc)
            label = 1 if mod_mvc == orig_mvc else 0
            labels.append(label)
        print(f"label presreved: {labels.count(1)}")
        combined_embeddings = [torch.cat((mod_emb, orig_emb)) for mod_emb, orig_emb in zip(self.modified_graph_embeddings, self.original_graph_embeddings)]
        # 将嵌入和标签转换为张量
        combined_embeddings_tensor = torch.stack(combined_embeddings)
        # combined_embeddings_tensor shape : torch.Size([50, 2*graph embedding]) 兩張graph的嵌入拼接起來
        self.labels_tensor = torch.tensor(labels).to(device)
        # labels_tensor shape : torch.Size([50]) 也就是50個graph的label
        self.preserve_predict = self.classifier(combined_embeddings_tensor).squeeze()
        # preserve_predict shape: torch.Size([50])也就是50個graph預測的label
        return self.cosine_similarities, self.preserve_predict, self.labels_tensor, MVC_diff/self.GraphNumber
        
        
    def init_graph(self):
        """construct or load training graph and use Node2vec to get node embedding"""
        self.train_graphs = pickle_load("/workspace/Synthetic_graph/Training_graph_50.pkl")
        self.create_edge_dict(self.Graphsize)
        for i in range(self.GraphNumber):
            # p = random.uniform(graph_density[0], graph_density[1])
            # G = nx.erdos_renyi_graph(graph_size, p)
            G = self.train_graphs[i]
            adj_matrix = nx.adjacency_matrix(G)
            adj_matrix = coo_matrix(adj_matrix)

            row = torch.from_numpy(adj_matrix.row.astype(np.int64))
            col = torch.from_numpy(adj_matrix.col.astype(np.int64))
            edge_index = torch.stack([row, col], dim=0)
            vec = Node2Vec(G, dimensions=50, walk_length=10, num_walks=10, workers=4, quiet=True)
            InitNodeEmb = vec.fit(window=3, min_count=2, batch_words=4)
            embeddings = InitNodeEmb.wv
            x = torch.tensor(embeddings.vectors, dtype=torch.float32)
            # x = torch.eye(G.number_of_nodes())  # 节点特征

            data = Data(x=x, edge_index=edge_index)
            self.dataset.append(data)
            
    def create_edge_dict(self,graph_size):
        """mapping edge to index"""
        index = 0
        for i in range(graph_size - 1):
            for j in range(i + 1, graph_size):
                self.whole_edge_set.add((i, j))
                self.edge_dict[(i, j)] = index
                index += 1
        
    def calculate_MVC(self,graph, UB=9999999, C=set()):
        """use branch and bound to find out the mvc result"""
        if len(graph.edges()) == 0:
            return C

        v, _ = max(graph.degree(), key=lambda a: a[1])
        # C1 分支：選擇鄰居
        C1 = C.copy()
        neighbors = set(graph.neighbors(v))
        C1.update(neighbors)
        graph_1 = graph.copy()
        graph_1.remove_nodes_from(neighbors)
        if len(C1) < UB:
            C1 = self.calculate_MVC(graph_1, UB, C1)

        # C2 分支：只選擇該節點
        C2 = C.copy()
        C2.add(v)
        graph_2 = graph.copy()
        graph_2.remove_node(v)
        if len(C2) < UB:
            C2 = self.calculate_MVC(graph_2, min(UB, len(C1)), C2)

        return min(C1, C2, key=len)
    
    def get_graph_embedding(self,embeddings):
        """average all node embeddings to get graph embedding"""
        graph_embeddings = []
        for embedding in embeddings:
            graph_embedding = embedding.mean(dim=0)  # 对所有节点嵌入求平均
            graph_embeddings.append(graph_embedding)
        return torch.stack(graph_embeddings)
    
    def generate_edge_embeddings(self,data, embedding, graph_emb):
        """generate and sample edge embeddings for training 需要修改"""
        data= to_networkx(data, to_undirected=True)
        edge_set = set(data.edges()) 
        combined_embeddings = []
        pro_list = []
        print(f"len of edge_set: {len(edge_set)}, len of whole_edge_set: {len(self.whole_edge_set)}, len of none edge: {len(self.whole_edge_set) - len(edge_set)}")
        for u,v in self.whole_edge_set:
            node1_emb = embedding[u]
            node2_emb = embedding[v]
            if (u,v) in edge_set:
                node_pair_emb = torch.cat([node1_emb, node2_emb, torch.tensor([1.0]).to(device), graph_emb])
                probabilities = self.mlp(node_pair_emb).squeeze()
                pro_list.append((probabilities,(u,v)))
            else:
                node_pair_emb = torch.cat([node1_emb, node2_emb, torch.tensor([0.0]).to(device), graph_emb])
                probabilities = self.mlp(node_pair_emb).squeeze()
                pro_list.append((probabilities.item(),(u,v)))
        pro_list = sorted(pro_list, key=lambda x: x[0], reverse=True)
        # print(pro_list)
        combined_embeddings = pro_list[:self.modified_edge]
        return combined_embeddings
    def validation(self):
        validation_data, valid_opt, pro = pickle_load("/workspace/Synthetic_graph/Validation_graph_200_withOPTPRO.pkl")
        valid_original_embeddings = []
        self.valid_dataset = []
        self.valid_modified_graphs = []
        # 把validation data轉成pyg的data，並透過node2vec得到node feature，再輸入GAT得到node embedding，最後透過get_graph_embedding得到graph embedding
        for i in range(len(validation_data)):
            G = validation_data[i]
            adj_matrix = nx.adjacency_matrix(G)
            adj_matrix = coo_matrix(adj_matrix)

            row = torch.from_numpy(adj_matrix.row.astype(np.int64))
            col = torch.from_numpy(adj_matrix.col.astype(np.int64))
            edge_index = torch.stack([row, col], dim=0)
            vec = Node2Vec(G, dimensions=50, walk_length=10, num_walks=10, workers=4, quiet=True)
            InitNodeEmb = vec.fit(window=3, min_count=2, batch_words=4)
            embeddings = InitNodeEmb.wv
            x = torch.tensor(embeddings.vectors, dtype=torch.float32)

            data = Data(x=x, edge_index=edge_index)
            self.valid_dataset.append(data)
            data = data.to(device)
            embedding = self.gat(data)
            valid_original_embeddings.append(embedding)
        self.valid_graph_embedding = self.get_graph_embedding(valid_original_embeddings)
        
        # 將每個graph的node embedding和graph embedding還有pyg data輸入generate_edge_embeddings得到要修改的edge，並直接修改成新的graph，用valid_modified_graphs儲存
        for emb, data, graph_emb in zip(valid_original_embeddings, self.valid_dataset, self.valid_graph_embedding):
            modify_edge = self.generate_edge_embeddings(data, emb, graph_emb) #pyg data是為了知道邊
            G = to_networkx(data, to_undirected=True)
            for decision in modify_edge:
                edge = decision[1]
                if (G.has_edge(edge[0], edge[1])):
                    G.remove_edge(edge[0], edge[1])
                else:
                    G.add_edge(edge[0], edge[1])
            self.valid_modified_graphs.append(G)
        
        valid_label_presever = 0
        for val_mod_graph, ori_opt in zip(self.valid_modified_graphs, valid_opt):
            mod_mvc = len(self.calculate_MVC(val_mod_graph))
            if ori_opt == mod_mvc:
                valid_label_presever += 1
        print(f"validation label presreved: {valid_label_presever}")

# %%
mymodel = Modify_edge(num_features=50, graph_embedding_size=graph_embedding_size, epoch=100, lr=0.0001, modified_edge=edge_sample_number, device=device, GraphNumber=50, Graphsize=50, num_heads=4)
mymodel = mymodel.to(device)
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(mymodel.parameters(), lr=0.00005)

# %%
diff_weight = 2
for epoch in range(100):
    mymodel.train()
    similarity_loss , preserve_predict, labels_tensor, difference_loss = mymodel()
    classifier_loss = criterion(preserve_predict, labels_tensor.float())
    loss = classifier_loss + similarity_loss + difference_loss
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    print(f"Epoch: {epoch}, Loss: {loss}, similarity_loss: {similarity_loss}, difference_loss: {difference_loss}")
    mymodel.eval()
    with torch.no_grad():
        mymodel.validation()
# Out:
# len of edge_set: 853, len of whole_edge_set: 1225, len of none edge: 372
# add_num: 100, delete_num: 0
# len of edge_set: 750, len of whole_edge_set: 1225, len of none edge: 475
# add_num: 100, delete_num: 0
# len of edge_set: 818, len of whole_edge_set: 1225, len of none edge: 407
# add_num: 100, delete_num: 0
# len of edge_set: 722, len of whole_edge_set: 1225, len of none edge: 503
# add_num: 100, delete_num: 0
# len of edge_set: 331, len of whole_edge_set: 1225, len of none edge: 894
# add_num: 100, delete_num: 0
# len of edge_set: 913, len of whole_edge_set: 1225, len of none edge: 312
# add_num: 100, delete_num: 0
# len of edge_set: 534, len of whole_edge_set: 1225, len of none edge: 691
# add_num: 100, delete_num: 0
# len of edge_set: 432, len of whole_edge_set: 1225, len of none edge: 793
# add_num: 100, delete_num: 0
# len of edge_set: 576, len of whole_edge_set: 1225, len of none edge: 649
# add_num: 100, delete_num: 0
# len of edge_set: 443, len of whole_edge_set: 1225, len of none edge: 782
# add_num: 100, delete_num: 0
# len of edge_set: 781, len of whole_edge_set: 1225, len of none edge: 444
# add_num: 100, delete_num: 0
# len of edge_set: 801, len of whole_edge_set: 1225, len of none edge: 424
# add_num: 100, delete_num: 0
# len of edge_set: 491, len of whole_edge_set: 1225, len of none edge: 734
# add_num: 100, delete_num: 0
# len of edge_set: 735, len of whole_edge_set: 1225, len of none edge: 490
# add_num: 100, delete_num: 0
# len of edge_set: 571, len of whole_edge_set: 1225, len of none edge: 654
# add_num: 100, delete_num: 0
# len of edge_set: 715, len of whole_edge_set: 1225, len of none edge: 510
# add_num: 100, delete_num: 0
# len of edge_set: 784, len of whole_edge_set: 1225, len of none edge: 441
# add_num: 100, delete_num: 0
# len of edge_set: 476, len of whole_edge_set: 1225, len of none edge: 749
# add_num: 100, delete_num: 0
# len of edge_set: 524, len of whole_edge_set: 1225, len of none edge: 701
# add_num: 100, delete_num: 0
# len of edge_set: 799, len of whole_edge_set: 1225, len of none edge: 426
# add_num: 100, delete_num: 0
# len of edge_set: 433, len of whole_edge_set: 1225, len of none edge: 792
# add_num: 100, delete_num: 0
# len of edge_set: 816, len of whole_edge_set: 1225, len of none edge: 409
# add_num: 100, delete_num: 0
# len of edge_set: 703, len of whole_edge_set: 1225, len of none edge: 522
# add_num: 100, delete_num: 0
# len of edge_set: 428, len of whole_edge_set: 1225, len of none edge: 797
# add_num: 100, delete_num: 0
# len of edge_set: 402, len of whole_edge_set: 1225, len of none edge: 823
# add_num: 100, delete_num: 0
# len of edge_set: 415, len of whole_edge_set: 1225, len of none edge: 810
# add_num: 100, delete_num: 0
# len of edge_set: 895, len of whole_edge_set: 1225, len of none edge: 330
# add_num: 100, delete_num: 0
# len of edge_set: 890, len of whole_edge_set: 1225, len of none edge: 335
# add_num: 100, delete_num: 0
# len of edge_set: 402, len of whole_edge_set: 1225, len of none edge: 823
# add_num: 100, delete_num: 0
# len of edge_set: 697, len of whole_edge_set: 1225, len of none edge: 528
# add_num: 100, delete_num: 0
# len of edge_set: 558, len of whole_edge_set: 1225, len of none edge: 667
# add_num: 100, delete_num: 0
# len of edge_set: 740, len of whole_edge_set: 1225, len of none edge: 485
# add_num: 100, delete_num: 0
# len of edge_set: 379, len of whole_edge_set: 1225, len of none edge: 846
# add_num: 100, delete_num: 0
# len of edge_set: 370, len of whole_edge_set: 1225, len of none edge: 855
# add_num: 100, delete_num: 0
# len of edge_set: 817, len of whole_edge_set: 1225, len of none edge: 408
# add_num: 100, delete_num: 0
# len of edge_set: 426, len of whole_edge_set: 1225, len of none edge: 799
# add_num: 100, delete_num: 0
# len of edge_set: 763, len of whole_edge_set: 1225, len of none edge: 462
# add_num: 100, delete_num: 0
# len of edge_set: 467, len of whole_edge_set: 1225, len of none edge: 758
# add_num: 100, delete_num: 0
# len of edge_set: 494, len of whole_edge_set: 1225, len of none edge: 731
# add_num: 100, delete_num: 0
# len of edge_set: 481, len of whole_edge_set: 1225, len of none edge: 744
# add_num: 100, delete_num: 0
# len of edge_set: 668, len of whole_edge_set: 1225, len of none edge: 557
# add_num: 100, delete_num: 0
# len of edge_set: 704, len of whole_edge_set: 1225, len of none edge: 521
# add_num: 100, delete_num: 0
# len of edge_set: 653, len of whole_edge_set: 1225, len of none edge: 572
# add_num: 100, delete_num: 0
# len of edge_set: 701, len of whole_edge_set: 1225, len of none edge: 524
# add_num: 100, delete_num: 0
# len of edge_set: 630, len of whole_edge_set: 1225, len of none edge: 595
# add_num: 100, delete_num: 0
# len of edge_set: 598, len of whole_edge_set: 1225, len of none edge: 627
# add_num: 100, delete_num: 0
# len of edge_set: 326, len of whole_edge_set: 1225, len of none edge: 899
# add_num: 100, delete_num: 0
# len of edge_set: 456, len of whole_edge_set: 1225, len of none edge: 769
# add_num: 100, delete_num: 0
# len of edge_set: 453, len of whole_edge_set: 1225, len of none edge: 772
# add_num: 100, delete_num: 0
# len of edge_set: 467, len of whole_edge_set: 1225, len of none edge: 758
# add_num: 100, delete_num: 0
# label presreved: 15
# Epoch: 0, Loss: 2.8060545921325684, similarity_loss: 0.936974287033081, difference_loss: 1.18
# len of edge_set: 851, len of whole_edge_set: 1225, len of none edge: 374
# len of edge_set: 741, len of whole_edge_set: 1225, len of none edge: 484
# len of edge_set: 416, len of whole_edge_set: 1225, len of none edge: 809
# len of edge_set: 713, len of whole_edge_set: 1225, len of none edge: 512
# len of edge_set: 392, len of whole_edge_set: 1225, len of none edge: 833
# len of edge_set: 390, len of whole_edge_set: 1225, len of none edge: 835
# len of edge_set: 307, len of whole_edge_set: 1225, len of none edge: 918
# len of edge_set: 339, len of whole_edge_set: 1225, len of none edge: 886
# len of edge_set: 385, len of whole_edge_set: 1225, len of none edge: 840
# len of edge_set: 741, len of whole_edge_set: 1225, len of none edge: 484
# len of edge_set: 367, len of whole_edge_set: 1225, len of none edge: 858
# len of edge_set: 769, len of whole_edge_set: 1225, len of none edge: 456
# len of edge_set: 605, len of whole_edge_set: 1225, len of none edge: 620
# len of edge_set: 898, len of whole_edge_set: 1225, len of none edge: 327
# len of edge_set: 369, len of whole_edge_set: 1225, len of none edge: 856
# len of edge_set: 350, len of whole_edge_set: 1225, len of none edge: 875
# len of edge_set: 435, len of whole_edge_set: 1225, len of none edge: 790
# len of edge_set: 476, len of whole_edge_set: 1225, len of none edge: 749
# len of edge_set: 551, len of whole_edge_set: 1225, len of none edge: 674
# len of edge_set: 390, len of whole_edge_set: 1225, len of none edge: 835
# len of edge_set: 781, len of whole_edge_set: 1225, len of none edge: 444
# len of edge_set: 796, len of whole_edge_set: 1225, len of none edge: 429
# len of edge_set: 449, len of whole_edge_set: 1225, len of none edge: 776
# len of edge_set: 570, len of whole_edge_set: 1225, len of none edge: 655
# len of edge_set: 775, len of whole_edge_set: 1225, len of none edge: 450
# len of edge_set: 828, len of whole_edge_set: 1225, len of none edge: 397
# len of edge_set: 282, len of whole_edge_set: 1225, len of none edge: 943
# len of edge_set: 508, len of whole_edge_set: 1225, len of none edge: 717
# len of edge_set: 862, len of whole_edge_set: 1225, len of none edge: 363
# len of edge_set: 599, len of whole_edge_set: 1225, len of none edge: 626
# len of edge_set: 478, len of whole_edge_set: 1225, len of none edge: 747
# len of edge_set: 403, len of whole_edge_set: 1225, len of none edge: 822
# len of edge_set: 746, len of whole_edge_set: 1225, len of none edge: 479
# len of edge_set: 370, len of whole_edge_set: 1225, len of none edge: 855
# len of edge_set: 513, len of whole_edge_set: 1225, len of none edge: 712
# len of edge_set: 699, len of whole_edge_set: 1225, len of none edge: 526
# len of edge_set: 582, len of whole_edge_set: 1225, len of none edge: 643
# len of edge_set: 905, len of whole_edge_set: 1225, len of none edge: 320
# len of edge_set: 387, len of whole_edge_set: 1225, len of none edge: 838
# len of edge_set: 343, len of whole_edge_set: 1225, len of none edge: 882
# len of edge_set: 556, len of whole_edge_set: 1225, len of none edge: 669
# len of edge_set: 903, len of whole_edge_set: 1225, len of none edge: 322
# len of edge_set: 647, len of whole_edge_set: 1225, len of none edge: 578
# len of edge_set: 430, len of whole_edge_set: 1225, len of none edge: 795
# len of edge_set: 593, len of whole_edge_set: 1225, len of none edge: 632
# len of edge_set: 558, len of whole_edge_set: 1225, len of none edge: 667
# len of edge_set: 496, len of whole_edge_set: 1225, len of none edge: 729
# len of edge_set: 784, len of whole_edge_set: 1225, len of none edge: 441
# len of edge_set: 623, len of whole_edge_set: 1225, len of none edge: 602
# len of edge_set: 699, len of whole_edge_set: 1225, len of none edge: 526
# len of edge_set: 767, len of whole_edge_set: 1225, len of none edge: 458
# len of edge_set: 811, len of whole_edge_set: 1225, len of none edge: 414
# len of edge_set: 375, len of whole_edge_set: 1225, len of none edge: 850
# len of edge_set: 370, len of whole_edge_set: 1225, len of none edge: 855
# len of edge_set: 876, len of whole_edge_set: 1225, len of none edge: 349
# len of edge_set: 851, len of whole_edge_set: 1225, len of none edge: 374
# len of edge_set: 625, len of whole_edge_set: 1225, len of none edge: 600
# len of edge_set: 475, len of whole_edge_set: 1225, len of none edge: 750
# len of edge_set: 439, len of whole_edge_set: 1225, len of none edge: 786
# len of edge_set: 459, len of whole_edge_set: 1225, len of none edge: 766
# len of edge_set: 880, len of whole_edge_set: 1225, len of none edge: 345
# len of edge_set: 736, len of whole_edge_set: 1225, len of none edge: 489
# len of edge_set: 585, len of whole_edge_set: 1225, len of none edge: 640
# len of edge_set: 516, len of whole_edge_set: 1225, len of none edge: 709
# len of edge_set: 490, len of whole_edge_set: 1225, len of none edge: 735
# len of edge_set: 686, len of whole_edge_set: 1225, len of none edge: 539
# len of edge_set: 438, len of whole_edge_set: 1225, len of none edge: 787
# len of edge_set: 351, len of whole_edge_set: 1225, len of none edge: 874
# len of edge_set: 389, len of whole_edge_set: 1225, len of none edge: 836
# len of edge_set: 671, len of whole_edge_set: 1225, len of none edge: 554
# len of edge_set: 545, len of whole_edge_set: 1225, len of none edge: 680
# len of edge_set: 922, len of whole_edge_set: 1225, len of none edge: 303
# len of edge_set: 486, len of whole_edge_set: 1225, len of none edge: 739
# len of edge_set: 753, len of whole_edge_set: 1225, len of none edge: 472
# len of edge_set: 370, len of whole_edge_set: 1225, len of none edge: 855
# len of edge_set: 636, len of whole_edge_set: 1225, len of none edge: 589
# len of edge_set: 888, len of whole_edge_set: 1225, len of none edge: 337
# len of edge_set: 587, len of whole_edge_set: 1225, len of none edge: 638
# len of edge_set: 412, len of whole_edge_set: 1225, len of none edge: 813
# len of edge_set: 576, len of whole_edge_set: 1225, len of none edge: 649
# len of edge_set: 809, len of whole_edge_set: 1225, len of none edge: 416
# len of edge_set: 904, len of whole_edge_set: 1225, len of none edge: 321
# len of edge_set: 887, len of whole_edge_set: 1225, len of none edge: 338
# len of edge_set: 566, len of whole_edge_set: 1225, len of none edge: 659
# len of edge_set: 423, len of whole_edge_set: 1225, len of none edge: 802
# len of edge_set: 668, len of whole_edge_set: 1225, len of none edge: 557
# len of edge_set: 873, len of whole_edge_set: 1225, len of none edge: 352
# len of edge_set: 565, len of whole_edge_set: 1225, len of none edge: 660
# len of edge_set: 365, len of whole_edge_set: 1225, len of none edge: 860
# len of edge_set: 356, len of whole_edge_set: 1225, len of none edge: 869
# len of edge_set: 531, len of whole_edge_set: 1225, len of none edge: 694
# len of edge_set: 760, len of whole_edge_set: 1225, len of none edge: 465
# len of edge_set: 388, len of whole_edge_set: 1225, len of none edge: 837
# len of edge_set: 670, len of whole_edge_set: 1225, len of none edge: 555
# len of edge_set: 675, len of whole_edge_set: 1225, len of none edge: 550
# len of edge_set: 648, len of whole_edge_set: 1225, len of none edge: 577
# len of edge_set: 417, len of whole_edge_set: 1225, len of none edge: 808
# len of edge_set: 853, len of whole_edge_set: 1225, len of none edge: 372
# len of edge_set: 877, len of whole_edge_set: 1225, len of none edge: 348
# len of edge_set: 582, len of whole_edge_set: 1225, len of none edge: 643
# len of edge_set: 676, len of whole_edge_set: 1225, len of none edge: 549
# len of edge_set: 514, len of whole_edge_set: 1225, len of none edge: 711
# len of edge_set: 834, len of whole_edge_set: 1225, len of none edge: 391
# len of edge_set: 854, len of whole_edge_set: 1225, len of none edge: 371
# len of edge_set: 832, len of whole_edge_set: 1225, len of none edge: 393
# len of edge_set: 905, len of whole_edge_set: 1225, len of none edge: 320
# len of edge_set: 741, len of whole_edge_set: 1225, len of none edge: 484
# len of edge_set: 599, len of whole_edge_set: 1225, len of none edge: 626
# len of edge_set: 352, len of whole_edge_set: 1225, len of none edge: 873
# len of edge_set: 532, len of whole_edge_set: 1225, len of none edge: 693
# len of edge_set: 310, len of whole_edge_set: 1225, len of none edge: 915
# len of edge_set: 707, len of whole_edge_set: 1225, len of none edge: 518
# len of edge_set: 865, len of whole_edge_set: 1225, len of none edge: 360
# len of edge_set: 414, len of whole_edge_set: 1225, len of none edge: 811
# len of edge_set: 572, len of whole_edge_set: 1225, len of none edge: 653
# len of edge_set: 447, len of whole_edge_set: 1225, len of none edge: 778
# len of edge_set: 347, len of whole_edge_set: 1225, len of none edge: 878
# len of edge_set: 901, len of whole_edge_set: 1225, len of none edge: 324
# len of edge_set: 564, len of whole_edge_set: 1225, len of none edge: 661
# len of edge_set: 496, len of whole_edge_set: 1225, len of none edge: 729
# len of edge_set: 645, len of whole_edge_set: 1225, len of none edge: 580
# len of edge_set: 784, len of whole_edge_set: 1225, len of none edge: 441
# len of edge_set: 815, len of whole_edge_set: 1225, len of none edge: 410
# len of edge_set: 312, len of whole_edge_set: 1225, len of none edge: 913
# len of edge_set: 854, len of whole_edge_set: 1225, len of none edge: 371
# len of edge_set: 730, len of whole_edge_set: 1225, len of none edge: 495
# len of edge_set: 584, len of whole_edge_set: 1225, len of none edge: 641
# len of edge_set: 359, len of whole_edge_set: 1225, len of none edge: 866
# len of edge_set: 321, len of whole_edge_set: 1225, len of none edge: 904
# len of edge_set: 444, len of whole_edge_set: 1225, len of none edge: 781
# len of edge_set: 729, len of whole_edge_set: 1225, len of none edge: 496
# len of edge_set: 586, len of whole_edge_set: 1225, len of none edge: 639
# len of edge_set: 403, len of whole_edge_set: 1225, len of none edge: 822
# len of edge_set: 333, len of whole_edge_set: 1225, len of none edge: 892
# len of edge_set: 612, len of whole_edge_set: 1225, len of none edge: 613
# len of edge_set: 642, len of whole_edge_set: 1225, len of none edge: 583
# len of edge_set: 921, len of whole_edge_set: 1225, len of none edge: 304
# len of edge_set: 872, len of whole_edge_set: 1225, len of none edge: 353
# len of edge_set: 719, len of whole_edge_set: 1225, len of none edge: 506
# len of edge_set: 508, len of whole_edge_set: 1225, len of none edge: 717
# len of edge_set: 584, len of whole_edge_set: 1225, len of none edge: 641
# len of edge_set: 719, len of whole_edge_set: 1225, len of none edge: 506
# len of edge_set: 783, len of whole_edge_set: 1225, len of none edge: 442
# len of edge_set: 801, len of whole_edge_set: 1225, len of none edge: 424
# len of edge_set: 659, len of whole_edge_set: 1225, len of none edge: 566
# len of edge_set: 317, len of whole_edge_set: 1225, len of none edge: 908
# len of edge_set: 779, len of whole_edge_set: 1225, len of none edge: 446
# len of edge_set: 712, len of whole_edge_set: 1225, len of none edge: 513
# len of edge_set: 894, len of whole_edge_set: 1225, len of none edge: 331
# len of edge_set: 434, len of whole_edge_set: 1225, len of none edge: 791
# len of edge_set: 851, len of whole_edge_set: 1225, len of none edge: 374
# len of edge_set: 579, len of whole_edge_set: 1225, len of none edge: 646
# len of edge_set: 905, len of whole_edge_set: 1225, len of none edge: 320
# len of edge_set: 755, len of whole_edge_set: 1225, len of none edge: 470
# len of edge_set: 755, len of whole_edge_set: 1225, len of none edge: 470
# len of edge_set: 737, len of whole_edge_set: 1225, len of none edge: 488
# len of edge_set: 806, len of whole_edge_set: 1225, len of none edge: 419
# len of edge_set: 592, len of whole_edge_set: 1225, len of none edge: 633
# len of edge_set: 443, len of whole_edge_set: 1225, len of none edge: 782
# len of edge_set: 810, len of whole_edge_set: 1225, len of none edge: 415
# len of edge_set: 731, len of whole_edge_set: 1225, len of none edge: 494
# len of edge_set: 733, len of whole_edge_set: 1225, len of none edge: 492
# len of edge_set: 721, len of whole_edge_set: 1225, len of none edge: 504
# len of edge_set: 386, len of whole_edge_set: 1225, len of none edge: 839
# len of edge_set: 713, len of whole_edge_set: 1225, len of none edge: 512
# len of edge_set: 364, len of whole_edge_set: 1225, len of none edge: 861
# len of edge_set: 861, len of whole_edge_set: 1225, len of none edge: 364
# len of edge_set: 529, len of whole_edge_set: 1225, len of none edge: 696
# len of edge_set: 835, len of whole_edge_set: 1225, len of none edge: 390
# len of edge_set: 814, len of whole_edge_set: 1225, len of none edge: 411
# len of edge_set: 821, len of whole_edge_set: 1225, len of none edge: 404
# len of edge_set: 908, len of whole_edge_set: 1225, len of none edge: 317
# len of edge_set: 373, len of whole_edge_set: 1225, len of none edge: 852
# len of edge_set: 671, len of whole_edge_set: 1225, len of none edge: 554
# len of edge_set: 692, len of whole_edge_set: 1225, len of none edge: 533
# len of edge_set: 445, len of whole_edge_set: 1225, len of none edge: 780
# len of edge_set: 437, len of whole_edge_set: 1225, len of none edge: 788
# len of edge_set: 543, len of whole_edge_set: 1225, len of none edge: 682
# len of edge_set: 506, len of whole_edge_set: 1225, len of none edge: 719
# len of edge_set: 509, len of whole_edge_set: 1225, len of none edge: 716
# len of edge_set: 757, len of whole_edge_set: 1225, len of none edge: 468
# len of edge_set: 601, len of whole_edge_set: 1225, len of none edge: 624
# len of edge_set: 831, len of whole_edge_set: 1225, len of none edge: 394
# len of edge_set: 766, len of whole_edge_set: 1225, len of none edge: 459
# len of edge_set: 871, len of whole_edge_set: 1225, len of none edge: 354
# len of edge_set: 694, len of whole_edge_set: 1225, len of none edge: 531
# len of edge_set: 489, len of whole_edge_set: 1225, len of none edge: 736
# len of edge_set: 342, len of whole_edge_set: 1225, len of none edge: 883
# len of edge_set: 624, len of whole_edge_set: 1225, len of none edge: 601
# len of edge_set: 349, len of whole_edge_set: 1225, len of none edge: 876
# len of edge_set: 659, len of whole_edge_set: 1225, len of none edge: 566
# len of edge_set: 646, len of whole_edge_set: 1225, len of none edge: 579
# len of edge_set: 740, len of whole_edge_set: 1225, len of none edge: 485
# len of edge_set: 597, len of whole_edge_set: 1225, len of none edge: 628
# len of edge_set: 783, len of whole_edge_set: 1225, len of none edge: 442
# len of edge_set: 380, len of whole_edge_set: 1225, len of none edge: 845
# len of edge_set: 508, len of whole_edge_set: 1225, len of none edge: 717
# len of edge_set: 397, len of whole_edge_set: 1225, len of none edge: 828
# len of edge_set: 507, len of whole_edge_set: 1225, len of none edge: 718
# len of edge_set: 687, len of whole_edge_set: 1225, len of none edge: 538
# validation label presreved: 82
# len of edge_set: 853, len of whole_edge_set: 1225, len of none edge: 372
# add_num: 100, delete_num: 0
# len of edge_set: 750, len of whole_edge_set: 1225, len of none edge: 475
# add_num: 100, delete_num: 0
# len of edge_set: 818, len of whole_edge_set: 1225, len of none edge: 407
# add_num: 100, delete_num: 0
# len of edge_set: 722, len of whole_edge_set: 1225, len of none edge: 503
# add_num: 100, delete_num: 0
# len of edge_set: 331, len of whole_edge_set: 1225, len of none edge: 894
# add_num: 100, delete_num: 0
# len of edge_set: 913, len of whole_edge_set: 1225, len of none edge: 312
# add_num: 100, delete_num: 0
# len of edge_set: 534, len of whole_edge_set: 1225, len of none edge: 691
# add_num: 100, delete_num: 0
# len of edge_set: 432, len of whole_edge_set: 1225, len of none edge: 793
# add_num: 100, delete_num: 0
# len of edge_set: 576, len of whole_edge_set: 1225, len of none edge: 649
# add_num: 100, delete_num: 0
# len of edge_set: 443, len of whole_edge_set: 1225, len of none edge: 782
# add_num: 100, delete_num: 0
# len of edge_set: 781, len of whole_edge_set: 1225, len of none edge: 444
# add_num: 100, delete_num: 0
# len of edge_set: 801, len of whole_edge_set: 1225, len of none edge: 424
# add_num: 100, delete_num: 0
# len of edge_set: 491, len of whole_edge_set: 1225, len of none edge: 734
# add_num: 100, delete_num: 0
# len of edge_set: 735, len of whole_edge_set: 1225, len of none edge: 490
# add_num: 100, delete_num: 0
# len of edge_set: 571, len of whole_edge_set: 1225, len of none edge: 654
# add_num: 100, delete_num: 0
# len of edge_set: 715, len of whole_edge_set: 1225, len of none edge: 510
# add_num: 100, delete_num: 0
# len of edge_set: 784, len of whole_edge_set: 1225, len of none edge: 441
# add_num: 100, delete_num: 0
# len of edge_set: 476, len of whole_edge_set: 1225, len of none edge: 749
# add_num: 100, delete_num: 0
# len of edge_set: 524, len of whole_edge_set: 1225, len of none edge: 701
# add_num: 100, delete_num: 0
# len of edge_set: 799, len of whole_edge_set: 1225, len of none edge: 426
# add_num: 100, delete_num: 0
# len of edge_set: 433, len of whole_edge_set: 1225, len of none edge: 792
# add_num: 100, delete_num: 0
# len of edge_set: 816, len of whole_edge_set: 1225, len of none edge: 409
# add_num: 100, delete_num: 0
# len of edge_set: 703, len of whole_edge_set: 1225, len of none edge: 522
# add_num: 100, delete_num: 0
# len of edge_set: 428, len of whole_edge_set: 1225, len of none edge: 797
# add_num: 100, delete_num: 0
# len of edge_set: 402, len of whole_edge_set: 1225, len of none edge: 823
# add_num: 100, delete_num: 0
# len of edge_set: 415, len of whole_edge_set: 1225, len of none edge: 810
# add_num: 100, delete_num: 0
# len of edge_set: 895, len of whole_edge_set: 1225, len of none edge: 330
# add_num: 100, delete_num: 0
# len of edge_set: 890, len of whole_edge_set: 1225, len of none edge: 335
# add_num: 100, delete_num: 0
# len of edge_set: 402, len of whole_edge_set: 1225, len of none edge: 823
# add_num: 100, delete_num: 0
# len of edge_set: 697, len of whole_edge_set: 1225, len of none edge: 528
# add_num: 100, delete_num: 0
# len of edge_set: 558, len of whole_edge_set: 1225, len of none edge: 667
# add_num: 100, delete_num: 0
# len of edge_set: 740, len of whole_edge_set: 1225, len of none edge: 485
# add_num: 100, delete_num: 0
# len of edge_set: 379, len of whole_edge_set: 1225, len of none edge: 846
# add_num: 100, delete_num: 0
# len of edge_set: 370, len of whole_edge_set: 1225, len of none edge: 855
# add_num: 100, delete_num: 0
# len of edge_set: 817, len of whole_edge_set: 1225, len of none edge: 408
# add_num: 100, delete_num: 0
# len of edge_set: 426, len of whole_edge_set: 1225, len of none edge: 799
# add_num: 100, delete_num: 0
# len of edge_set: 763, len of whole_edge_set: 1225, len of none edge: 462
# add_num: 100, delete_num: 0
# len of edge_set: 467, len of whole_edge_set: 1225, len of none edge: 758
# add_num: 100, delete_num: 0
# len of edge_set: 494, len of whole_edge_set: 1225, len of none edge: 731
# add_num: 100, delete_num: 0
# len of edge_set: 481, len of whole_edge_set: 1225, len of none edge: 744
# add_num: 100, delete_num: 0
# len of edge_set: 668, len of whole_edge_set: 1225, len of none edge: 557
# add_num: 100, delete_num: 0
# len of edge_set: 704, len of whole_edge_set: 1225, len of none edge: 521
# add_num: 100, delete_num: 0
# len of edge_set: 653, len of whole_edge_set: 1225, len of none edge: 572
# add_num: 100, delete_num: 0
# len of edge_set: 701, len of whole_edge_set: 1225, len of none edge: 524
# add_num: 100, delete_num: 0
# len of edge_set: 630, len of whole_edge_set: 1225, len of none edge: 595
# add_num: 100, delete_num: 0
# len of edge_set: 598, len of whole_edge_set: 1225, len of none edge: 627
# add_num: 100, delete_num: 0
# len of edge_set: 326, len of whole_edge_set: 1225, len of none edge: 899
# add_num: 100, delete_num: 0
# len of edge_set: 456, len of whole_edge_set: 1225, len of none edge: 769
# add_num: 100, delete_num: 0
# len of edge_set: 453, len of whole_edge_set: 1225, len of none edge: 772
# add_num: 100, delete_num: 0
# len of edge_set: 467, len of whole_edge_set: 1225, len of none edge: 758
# add_num: 100, delete_num: 0
# label presreved: 19
# Epoch: 1, Loss: 2.5713679790496826, similarity_loss: 0.9089822769165039, difference_loss: 0.98
# len of edge_set: 851, len of whole_edge_set: 1225, len of none edge: 374
# len of edge_set: 741, len of whole_edge_set: 1225, len of none edge: 484
# len of edge_set: 416, len of whole_edge_set: 1225, len of none edge: 809
# len of edge_set: 713, len of whole_edge_set: 1225, len of none edge: 512
# len of edge_set: 392, len of whole_edge_set: 1225, len of none edge: 833
# len of edge_set: 390, len of whole_edge_set: 1225, len of none edge: 835
# len of edge_set: 307, len of whole_edge_set: 1225, len of none edge: 918
# len of edge_set: 339, len of whole_edge_set: 1225, len of none edge: 886
# len of edge_set: 385, len of whole_edge_set: 1225, len of none edge: 840
# len of edge_set: 741, len of whole_edge_set: 1225, len of none edge: 484
# len of edge_set: 367, len of whole_edge_set: 1225, len of none edge: 858
# len of edge_set: 769, len of whole_edge_set: 1225, len of none edge: 456
# len of edge_set: 605, len of whole_edge_set: 1225, len of none edge: 620
# len of edge_set: 898, len of whole_edge_set: 1225, len of none edge: 327
# len of edge_set: 369, len of whole_edge_set: 1225, len of none edge: 856
# len of edge_set: 350, len of whole_edge_set: 1225, len of none edge: 875
# len of edge_set: 435, len of whole_edge_set: 1225, len of none edge: 790
# len of edge_set: 476, len of whole_edge_set: 1225, len of none edge: 749
# len of edge_set: 551, len of whole_edge_set: 1225, len of none edge: 674
# len of edge_set: 390, len of whole_edge_set: 1225, len of none edge: 835
# len of edge_set: 781, len of whole_edge_set: 1225, len of none edge: 444
# len of edge_set: 796, len of whole_edge_set: 1225, len of none edge: 429
# len of edge_set: 449, len of whole_edge_set: 1225, len of none edge: 776
# len of edge_set: 570, len of whole_edge_set: 1225, len of none edge: 655
# len of edge_set: 775, len of whole_edge_set: 1225, len of none edge: 450
# len of edge_set: 828, len of whole_edge_set: 1225, len of none edge: 397
# len of edge_set: 282, len of whole_edge_set: 1225, len of none edge: 943
# len of edge_set: 508, len of whole_edge_set: 1225, len of none edge: 717
# len of edge_set: 862, len of whole_edge_set: 1225, len of none edge: 363
# len of edge_set: 599, len of whole_edge_set: 1225, len of none edge: 626
# len of edge_set: 478, len of whole_edge_set: 1225, len of none edge: 747
# len of edge_set: 403, len of whole_edge_set: 1225, len of none edge: 822
# len of edge_set: 746, len of whole_edge_set: 1225, len of none edge: 479
# len of edge_set: 370, len of whole_edge_set: 1225, len of none edge: 855
# len of edge_set: 513, len of whole_edge_set: 1225, len of none edge: 712
# len of edge_set: 699, len of whole_edge_set: 1225, len of none edge: 526
# len of edge_set: 582, len of whole_edge_set: 1225, len of none edge: 643
# len of edge_set: 905, len of whole_edge_set: 1225, len of none edge: 320
# len of edge_set: 387, len of whole_edge_set: 1225, len of none edge: 838
# len of edge_set: 343, len of whole_edge_set: 1225, len of none edge: 882
# len of edge_set: 556, len of whole_edge_set: 1225, len of none edge: 669
# len of edge_set: 903, len of whole_edge_set: 1225, len of none edge: 322
# len of edge_set: 647, len of whole_edge_set: 1225, len of none edge: 578
# len of edge_set: 430, len of whole_edge_set: 1225, len of none edge: 795
# len of edge_set: 593, len of whole_edge_set: 1225, len of none edge: 632
# len of edge_set: 558, len of whole_edge_set: 1225, len of none edge: 667
# len of edge_set: 496, len of whole_edge_set: 1225, len of none edge: 729
# len of edge_set: 784, len of whole_edge_set: 1225, len of none edge: 441
# len of edge_set: 623, len of whole_edge_set: 1225, len of none edge: 602
# len of edge_set: 699, len of whole_edge_set: 1225, len of none edge: 526
# len of edge_set: 767, len of whole_edge_set: 1225, len of none edge: 458
# len of edge_set: 811, len of whole_edge_set: 1225, len of none edge: 414
# len of edge_set: 375, len of whole_edge_set: 1225, len of none edge: 850
# len of edge_set: 370, len of whole_edge_set: 1225, len of none edge: 855
# len of edge_set: 876, len of whole_edge_set: 1225, len of none edge: 349
# len of edge_set: 851, len of whole_edge_set: 1225, len of none edge: 374
# len of edge_set: 625, len of whole_edge_set: 1225, len of none edge: 600
# len of edge_set: 475, len of whole_edge_set: 1225, len of none edge: 750
# len of edge_set: 439, len of whole_edge_set: 1225, len of none edge: 786
# len of edge_set: 459, len of whole_edge_set: 1225, len of none edge: 766
# len of edge_set: 880, len of whole_edge_set: 1225, len of none edge: 345
# len of edge_set: 736, len of whole_edge_set: 1225, len of none edge: 489
# len of edge_set: 585, len of whole_edge_set: 1225, len of none edge: 640
# len of edge_set: 516, len of whole_edge_set: 1225, len of none edge: 709
# len of edge_set: 490, len of whole_edge_set: 1225, len of none edge: 735
# len of edge_set: 686, len of whole_edge_set: 1225, len of none edge: 539
# len of edge_set: 438, len of whole_edge_set: 1225, len of none edge: 787
# len of edge_set: 351, len of whole_edge_set: 1225, len of none edge: 874
# len of edge_set: 389, len of whole_edge_set: 1225, len of none edge: 836
# len of edge_set: 671, len of whole_edge_set: 1225, len of none edge: 554
# len of edge_set: 545, len of whole_edge_set: 1225, len of none edge: 680
# len of edge_set: 922, len of whole_edge_set: 1225, len of none edge: 303
# len of edge_set: 486, len of whole_edge_set: 1225, len of none edge: 739
# len of edge_set: 753, len of whole_edge_set: 1225, len of none edge: 472
# len of edge_set: 370, len of whole_edge_set: 1225, len of none edge: 855
# len of edge_set: 636, len of whole_edge_set: 1225, len of none edge: 589
# len of edge_set: 888, len of whole_edge_set: 1225, len of none edge: 337
# len of edge_set: 587, len of whole_edge_set: 1225, len of none edge: 638
# len of edge_set: 412, len of whole_edge_set: 1225, len of none edge: 813
# len of edge_set: 576, len of whole_edge_set: 1225, len of none edge: 649
# len of edge_set: 809, len of whole_edge_set: 1225, len of none edge: 416
# len of edge_set: 904, len of whole_edge_set: 1225, len of none edge: 321
# len of edge_set: 887, len of whole_edge_set: 1225, len of none edge: 338
# len of edge_set: 566, len of whole_edge_set: 1225, len of none edge: 659
# len of edge_set: 423, len of whole_edge_set: 1225, len of none edge: 802
# len of edge_set: 668, len of whole_edge_set: 1225, len of none edge: 557
# len of edge_set: 873, len of whole_edge_set: 1225, len of none edge: 352
# len of edge_set: 565, len of whole_edge_set: 1225, len of none edge: 660
# len of edge_set: 365, len of whole_edge_set: 1225, len of none edge: 860
# len of edge_set: 356, len of whole_edge_set: 1225, len of none edge: 869
# len of edge_set: 531, len of whole_edge_set: 1225, len of none edge: 694
# len of edge_set: 760, len of whole_edge_set: 1225, len of none edge: 465
# len of edge_set: 388, len of whole_edge_set: 1225, len of none edge: 837
# len of edge_set: 670, len of whole_edge_set: 1225, len of none edge: 555
# len of edge_set: 675, len of whole_edge_set: 1225, len of none edge: 550
# len of edge_set: 648, len of whole_edge_set: 1225, len of none edge: 577
# len of edge_set: 417, len of whole_edge_set: 1225, len of none edge: 808
# len of edge_set: 853, len of whole_edge_set: 1225, len of none edge: 372
# len of edge_set: 877, len of whole_edge_set: 1225, len of none edge: 348
# len of edge_set: 582, len of whole_edge_set: 1225, len of none edge: 643
# len of edge_set: 676, len of whole_edge_set: 1225, len of none edge: 549
# len of edge_set: 514, len of whole_edge_set: 1225, len of none edge: 711
# len of edge_set: 834, len of whole_edge_set: 1225, len of none edge: 391
# len of edge_set: 854, len of whole_edge_set: 1225, len of none edge: 371
# len of edge_set: 832, len of whole_edge_set: 1225, len of none edge: 393
# len of edge_set: 905, len of whole_edge_set: 1225, len of none edge: 320
# len of edge_set: 741, len of whole_edge_set: 1225, len of none edge: 484
# len of edge_set: 599, len of whole_edge_set: 1225, len of none edge: 626
# len of edge_set: 352, len of whole_edge_set: 1225, len of none edge: 873
# len of edge_set: 532, len of whole_edge_set: 1225, len of none edge: 693
# len of edge_set: 310, len of whole_edge_set: 1225, len of none edge: 915
# len of edge_set: 707, len of whole_edge_set: 1225, len of none edge: 518
# len of edge_set: 865, len of whole_edge_set: 1225, len of none edge: 360
# len of edge_set: 414, len of whole_edge_set: 1225, len of none edge: 811
# len of edge_set: 572, len of whole_edge_set: 1225, len of none edge: 653
# len of edge_set: 447, len of whole_edge_set: 1225, len of none edge: 778
# len of edge_set: 347, len of whole_edge_set: 1225, len of none edge: 878
# len of edge_set: 901, len of whole_edge_set: 1225, len of none edge: 324
# len of edge_set: 564, len of whole_edge_set: 1225, len of none edge: 661
# len of edge_set: 496, len of whole_edge_set: 1225, len of none edge: 729
# len of edge_set: 645, len of whole_edge_set: 1225, len of none edge: 580
# len of edge_set: 784, len of whole_edge_set: 1225, len of none edge: 441
# len of edge_set: 815, len of whole_edge_set: 1225, len of none edge: 410
# len of edge_set: 312, len of whole_edge_set: 1225, len of none edge: 913
# len of edge_set: 854, len of whole_edge_set: 1225, len of none edge: 371
# len of edge_set: 730, len of whole_edge_set: 1225, len of none edge: 495
# len of edge_set: 584, len of whole_edge_set: 1225, len of none edge: 641
# len of edge_set: 359, len of whole_edge_set: 1225, len of none edge: 866
# len of edge_set: 321, len of whole_edge_set: 1225, len of none edge: 904
# len of edge_set: 444, len of whole_edge_set: 1225, len of none edge: 781
# len of edge_set: 729, len of whole_edge_set: 1225, len of none edge: 496
# len of edge_set: 586, len of whole_edge_set: 1225, len of none edge: 639
# len of edge_set: 403, len of whole_edge_set: 1225, len of none edge: 822
# len of edge_set: 333, len of whole_edge_set: 1225, len of none edge: 892
# len of edge_set: 612, len of whole_edge_set: 1225, len of none edge: 613
# len of edge_set: 642, len of whole_edge_set: 1225, len of none edge: 583
# len of edge_set: 921, len of whole_edge_set: 1225, len of none edge: 304
# len of edge_set: 872, len of whole_edge_set: 1225, len of none edge: 353
# len of edge_set: 719, len of whole_edge_set: 1225, len of none edge: 506
# len of edge_set: 508, len of whole_edge_set: 1225, len of none edge: 717
# len of edge_set: 584, len of whole_edge_set: 1225, len of none edge: 641
# len of edge_set: 719, len of whole_edge_set: 1225, len of none edge: 506
# len of edge_set: 783, len of whole_edge_set: 1225, len of none edge: 442
# len of edge_set: 801, len of whole_edge_set: 1225, len of none edge: 424
# len of edge_set: 659, len of whole_edge_set: 1225, len of none edge: 566
# len of edge_set: 317, len of whole_edge_set: 1225, len of none edge: 908
# len of edge_set: 779, len of whole_edge_set: 1225, len of none edge: 446
# len of edge_set: 712, len of whole_edge_set: 1225, len of none edge: 513
# len of edge_set: 894, len of whole_edge_set: 1225, len of none edge: 331
# len of edge_set: 434, len of whole_edge_set: 1225, len of none edge: 791
# len of edge_set: 851, len of whole_edge_set: 1225, len of none edge: 374
# len of edge_set: 579, len of whole_edge_set: 1225, len of none edge: 646
# len of edge_set: 905, len of whole_edge_set: 1225, len of none edge: 320
# len of edge_set: 755, len of whole_edge_set: 1225, len of none edge: 470
# len of edge_set: 755, len of whole_edge_set: 1225, len of none edge: 470
# len of edge_set: 737, len of whole_edge_set: 1225, len of none edge: 488
# len of edge_set: 806, len of whole_edge_set: 1225, len of none edge: 419
# len of edge_set: 592, len of whole_edge_set: 1225, len of none edge: 633
# len of edge_set: 443, len of whole_edge_set: 1225, len of none edge: 782
# len of edge_set: 810, len of whole_edge_set: 1225, len of none edge: 415
# len of edge_set: 731, len of whole_edge_set: 1225, len of none edge: 494
# len of edge_set: 733, len of whole_edge_set: 1225, len of none edge: 492
# len of edge_set: 721, len of whole_edge_set: 1225, len of none edge: 504
# len of edge_set: 386, len of whole_edge_set: 1225, len of none edge: 839
# len of edge_set: 713, len of whole_edge_set: 1225, len of none edge: 512
# len of edge_set: 364, len of whole_edge_set: 1225, len of none edge: 861
# len of edge_set: 861, len of whole_edge_set: 1225, len of none edge: 364
# len of edge_set: 529, len of whole_edge_set: 1225, len of none edge: 696
# len of edge_set: 835, len of whole_edge_set: 1225, len of none edge: 390
# len of edge_set: 814, len of whole_edge_set: 1225, len of none edge: 411
# len of edge_set: 821, len of whole_edge_set: 1225, len of none edge: 404
# len of edge_set: 908, len of whole_edge_set: 1225, len of none edge: 317
# len of edge_set: 373, len of whole_edge_set: 1225, len of none edge: 852
# len of edge_set: 671, len of whole_edge_set: 1225, len of none edge: 554
# len of edge_set: 692, len of whole_edge_set: 1225, len of none edge: 533
# len of edge_set: 445, len of whole_edge_set: 1225, len of none edge: 780
# len of edge_set: 437, len of whole_edge_set: 1225, len of none edge: 788
# len of edge_set: 543, len of whole_edge_set: 1225, len of none edge: 682
# len of edge_set: 506, len of whole_edge_set: 1225, len of none edge: 719
# len of edge_set: 509, len of whole_edge_set: 1225, len of none edge: 716
# len of edge_set: 757, len of whole_edge_set: 1225, len of none edge: 468
# len of edge_set: 601, len of whole_edge_set: 1225, len of none edge: 624
# len of edge_set: 831, len of whole_edge_set: 1225, len of none edge: 394
# len of edge_set: 766, len of whole_edge_set: 1225, len of none edge: 459
# len of edge_set: 871, len of whole_edge_set: 1225, len of none edge: 354
# len of edge_set: 694, len of whole_edge_set: 1225, len of none edge: 531
# len of edge_set: 489, len of whole_edge_set: 1225, len of none edge: 736
# len of edge_set: 342, len of whole_edge_set: 1225, len of none edge: 883
# len of edge_set: 624, len of whole_edge_set: 1225, len of none edge: 601
# len of edge_set: 349, len of whole_edge_set: 1225, len of none edge: 876
# len of edge_set: 659, len of whole_edge_set: 1225, len of none edge: 566
# len of edge_set: 646, len of whole_edge_set: 1225, len of none edge: 579
# len of edge_set: 740, len of whole_edge_set: 1225, len of none edge: 485
# len of edge_set: 597, len of whole_edge_set: 1225, len of none edge: 628
# len of edge_set: 783, len of whole_edge_set: 1225, len of none edge: 442
# len of edge_set: 380, len of whole_edge_set: 1225, len of none edge: 845
# len of edge_set: 508, len of whole_edge_set: 1225, len of none edge: 717
# len of edge_set: 397, len of whole_edge_set: 1225, len of none edge: 828
# len of edge_set: 507, len of whole_edge_set: 1225, len of none edge: 718
# len of edge_set: 687, len of whole_edge_set: 1225, len of none edge: 538
# validation label presreved: 77
# len of edge_set: 853, len of whole_edge_set: 1225, len of none edge: 372
# add_num: 100, delete_num: 0
# len of edge_set: 750, len of whole_edge_set: 1225, len of none edge: 475
# add_num: 100, delete_num: 0
# len of edge_set: 818, len of whole_edge_set: 1225, len of none edge: 407
# add_num: 100, delete_num: 0
# len of edge_set: 722, len of whole_edge_set: 1225, len of none edge: 503
# add_num: 100, delete_num: 0
# len of edge_set: 331, len of whole_edge_set: 1225, len of none edge: 894
# add_num: 100, delete_num: 0
# len of edge_set: 913, len of whole_edge_set: 1225, len of none edge: 312
# add_num: 100, delete_num: 0
# len of edge_set: 534, len of whole_edge_set: 1225, len of none edge: 691
# add_num: 100, delete_num: 0
# len of edge_set: 432, len of whole_edge_set: 1225, len of none edge: 793
# add_num: 100, delete_num: 0
# len of edge_set: 576, len of whole_edge_set: 1225, len of none edge: 649
# add_num: 100, delete_num: 0
# len of edge_set: 443, len of whole_edge_set: 1225, len of none edge: 782
# add_num: 100, delete_num: 0
# len of edge_set: 781, len of whole_edge_set: 1225, len of none edge: 444
# add_num: 100, delete_num: 0
# len of edge_set: 801, len of whole_edge_set: 1225, len of none edge: 424
# add_num: 100, delete_num: 0
# len of edge_set: 491, len of whole_edge_set: 1225, len of none edge: 734
# add_num: 100, delete_num: 0
# len of edge_set: 735, len of whole_edge_set: 1225, len of none edge: 490
# add_num: 100, delete_num: 0
# len of edge_set: 571, len of whole_edge_set: 1225, len of none edge: 654
# add_num: 100, delete_num: 0
# len of edge_set: 715, len of whole_edge_set: 1225, len of none edge: 510
# add_num: 100, delete_num: 0
# len of edge_set: 784, len of whole_edge_set: 1225, len of none edge: 441
# add_num: 100, delete_num: 0
# len of edge_set: 476, len of whole_edge_set: 1225, len of none edge: 749
# add_num: 100, delete_num: 0
# len of edge_set: 524, len of whole_edge_set: 1225, len of none edge: 701
# add_num: 100, delete_num: 0
# len of edge_set: 799, len of whole_edge_set: 1225, len of none edge: 426
# add_num: 100, delete_num: 0
# len of edge_set: 433, len of whole_edge_set: 1225, len of none edge: 792
# add_num: 100, delete_num: 0
# len of edge_set: 816, len of whole_edge_set: 1225, len of none edge: 409
# add_num: 100, delete_num: 0
# len of edge_set: 703, len of whole_edge_set: 1225, len of none edge: 522
# add_num: 100, delete_num: 0
# len of edge_set: 428, len of whole_edge_set: 1225, len of none edge: 797
# add_num: 100, delete_num: 0
# len of edge_set: 402, len of whole_edge_set: 1225, len of none edge: 823
# add_num: 100, delete_num: 0
# len of edge_set: 415, len of whole_edge_set: 1225, len of none edge: 810
# add_num: 100, delete_num: 0
# len of edge_set: 895, len of whole_edge_set: 1225, len of none edge: 330
# add_num: 100, delete_num: 0
# len of edge_set: 890, len of whole_edge_set: 1225, len of none edge: 335
# add_num: 100, delete_num: 0
# len of edge_set: 402, len of whole_edge_set: 1225, len of none edge: 823
# add_num: 100, delete_num: 0
# len of edge_set: 697, len of whole_edge_set: 1225, len of none edge: 528
# add_num: 100, delete_num: 0
# len of edge_set: 558, len of whole_edge_set: 1225, len of none edge: 667
# add_num: 100, delete_num: 0
# len of edge_set: 740, len of whole_edge_set: 1225, len of none edge: 485
# add_num: 100, delete_num: 0
# len of edge_set: 379, len of whole_edge_set: 1225, len of none edge: 846
# add_num: 100, delete_num: 0
# len of edge_set: 370, len of whole_edge_set: 1225, len of none edge: 855
# add_num: 100, delete_num: 0
# len of edge_set: 817, len of whole_edge_set: 1225, len of none edge: 408
# add_num: 100, delete_num: 0
# len of edge_set: 426, len of whole_edge_set: 1225, len of none edge: 799
# add_num: 100, delete_num: 0
# len of edge_set: 763, len of whole_edge_set: 1225, len of none edge: 462
# add_num: 100, delete_num: 0
# len of edge_set: 467, len of whole_edge_set: 1225, len of none edge: 758
# add_num: 100, delete_num: 0
# len of edge_set: 494, len of whole_edge_set: 1225, len of none edge: 731
# add_num: 100, delete_num: 0
# len of edge_set: 481, len of whole_edge_set: 1225, len of none edge: 744
# add_num: 100, delete_num: 0
# len of edge_set: 668, len of whole_edge_set: 1225, len of none edge: 557
# add_num: 100, delete_num: 0
# len of edge_set: 704, len of whole_edge_set: 1225, len of none edge: 521
# add_num: 100, delete_num: 0
# len of edge_set: 653, len of whole_edge_set: 1225, len of none edge: 572
# add_num: 100, delete_num: 0
# len of edge_set: 701, len of whole_edge_set: 1225, len of none edge: 524
# add_num: 100, delete_num: 0
# len of edge_set: 630, len of whole_edge_set: 1225, len of none edge: 595
# add_num: 100, delete_num: 0
# len of edge_set: 598, len of whole_edge_set: 1225, len of none edge: 627
# add_num: 100, delete_num: 0
# len of edge_set: 326, len of whole_edge_set: 1225, len of none edge: 899
# add_num: 100, delete_num: 0
# len of edge_set: 456, len of whole_edge_set: 1225, len of none edge: 769
# add_num: 100, delete_num: 0
# len of edge_set: 453, len of whole_edge_set: 1225, len of none edge: 772
# add_num: 100, delete_num: 0
# len of edge_set: 467, len of whole_edge_set: 1225, len of none edge: 758
# add_num: 100, delete_num: 0
# label presreved: 15
# Epoch: 2, Loss: 2.6658835411071777, similarity_loss: 0.8742761015892029, difference_loss: 1.12
# len of edge_set: 851, len of whole_edge_set: 1225, len of none edge: 374
# len of edge_set: 741, len of whole_edge_set: 1225, len of none edge: 484
# len of edge_set: 416, len of whole_edge_set: 1225, len of none edge: 809
# len of edge_set: 713, len of whole_edge_set: 1225, len of none edge: 512
# len of edge_set: 392, len of whole_edge_set: 1225, len of none edge: 833
# len of edge_set: 390, len of whole_edge_set: 1225, len of none edge: 835
# len of edge_set: 307, len of whole_edge_set: 1225, len of none edge: 918
# len of edge_set: 339, len of whole_edge_set: 1225, len of none edge: 886
# len of edge_set: 385, len of whole_edge_set: 1225, len of none edge: 840
# len of edge_set: 741, len of whole_edge_set: 1225, len of none edge: 484
# len of edge_set: 367, len of whole_edge_set: 1225, len of none edge: 858
# len of edge_set: 769, len of whole_edge_set: 1225, len of none edge: 456
# len of edge_set: 605, len of whole_edge_set: 1225, len of none edge: 620
# len of edge_set: 898, len of whole_edge_set: 1225, len of none edge: 327
# len of edge_set: 369, len of whole_edge_set: 1225, len of none edge: 856
# len of edge_set: 350, len of whole_edge_set: 1225, len of none edge: 875
# len of edge_set: 435, len of whole_edge_set: 1225, len of none edge: 790
# len of edge_set: 476, len of whole_edge_set: 1225, len of none edge: 749
# len of edge_set: 551, len of whole_edge_set: 1225, len of none edge: 674
# len of edge_set: 390, len of whole_edge_set: 1225, len of none edge: 835
# len of edge_set: 781, len of whole_edge_set: 1225, len of none edge: 444
# len of edge_set: 796, len of whole_edge_set: 1225, len of none edge: 429
# len of edge_set: 449, len of whole_edge_set: 1225, len of none edge: 776
# len of edge_set: 570, len of whole_edge_set: 1225, len of none edge: 655
# len of edge_set: 775, len of whole_edge_set: 1225, len of none edge: 450
# len of edge_set: 828, len of whole_edge_set: 1225, len of none edge: 397
# len of edge_set: 282, len of whole_edge_set: 1225, len of none edge: 943
# len of edge_set: 508, len of whole_edge_set: 1225, len of none edge: 717
# len of edge_set: 862, len of whole_edge_set: 1225, len of none edge: 363
# len of edge_set: 599, len of whole_edge_set: 1225, len of none edge: 626
# len of edge_set: 478, len of whole_edge_set: 1225, len of none edge: 747
# len of edge_set: 403, len of whole_edge_set: 1225, len of none edge: 822
# len of edge_set: 746, len of whole_edge_set: 1225, len of none edge: 479
# len of edge_set: 370, len of whole_edge_set: 1225, len of none edge: 855
# len of edge_set: 513, len of whole_edge_set: 1225, len of none edge: 712
# len of edge_set: 699, len of whole_edge_set: 1225, len of none edge: 526
# len of edge_set: 582, len of whole_edge_set: 1225, len of none edge: 643
# len of edge_set: 905, len of whole_edge_set: 1225, len of none edge: 320
# len of edge_set: 387, len of whole_edge_set: 1225, len of none edge: 838
# len of edge_set: 343, len of whole_edge_set: 1225, len of none edge: 882
# len of edge_set: 556, len of whole_edge_set: 1225, len of none edge: 669
# len of edge_set: 903, len of whole_edge_set: 1225, len of none edge: 322
# len of edge_set: 647, len of whole_edge_set: 1225, len of none edge: 578
# len of edge_set: 430, len of whole_edge_set: 1225, len of none edge: 795
# ...
# len of edge_set: 375, len of whole_edge_set: 1225, len of none edge: 850
# len of edge_set: 370, len of whole_edge_set: 1225, len of none edge: 855
# len of edge_set: 876, len of whole_edge_set: 1225, len of none edge: 349
# len of edge_set: 851, len of whole_edge_set: 1225, len of none edge: 374
# len of edge_set: 625, len of whole_edge_set: 1225, len of none edge: 600
# len of edge_set: 475, len of whole_edge_set: 1225, len of none edge: 750
# len of edge_set: 439, len of whole_edge_set: 1225, len of none edge: 786
# len of edge_set: 459, len of whole_edge_set: 1225, len of none edge: 766
# len of edge_set: 880, len of whole_edge_set: 1225, len of none edge: 345
# len of edge_set: 736, len of whole_edge_set: 1225, len of none edge: 489
# len of edge_set: 585, len of whole_edge_set: 1225, len of none edge: 640
# len of edge_set: 516, len of whole_edge_set: 1225, len of none edge: 709
# len of edge_set: 490, len of whole_edge_set: 1225, len of none edge: 735
# len of edge_set: 686, len of whole_edge_set: 1225, len of none edge: 539
# len of edge_set: 438, len of whole_edge_set: 1225, len of none edge: 787
# len of edge_set: 351, len of whole_edge_set: 1225, len of none edge: 874
# len of edge_set: 389, len of whole_edge_set: 1225, len of none edge: 836
# len of edge_set: 671, len of whole_edge_set: 1225, len of none edge: 554
# len of edge_set: 545, len of whole_edge_set: 1225, len of none edge: 680
# len of edge_set: 922, len of whole_edge_set: 1225, len of none edge: 303
# len of edge_set: 486, len of whole_edge_set: 1225, len of none edge: 739
# len of edge_set: 753, len of whole_edge_set: 1225, len of none edge: 472
# len of edge_set: 370, len of whole_edge_set: 1225, len of none edge: 855
# len of edge_set: 636, len of whole_edge_set: 1225, len of none edge: 589
# len of edge_set: 888, len of whole_edge_set: 1225, len of none edge: 337
# len of edge_set: 587, len of whole_edge_set: 1225, len of none edge: 638
# len of edge_set: 412, len of whole_edge_set: 1225, len of none edge: 813
# len of edge_set: 576, len of whole_edge_set: 1225, len of none edge: 649
# len of edge_set: 809, len of whole_edge_set: 1225, len of none edge: 416
# len of edge_set: 904, len of whole_edge_set: 1225, len of none edge: 321
# len of edge_set: 887, len of whole_edge_set: 1225, len of none edge: 338
# len of edge_set: 566, len of whole_edge_set: 1225, len of none edge: 659
# len of edge_set: 423, len of whole_edge_set: 1225, len of none edge: 802
# len of edge_set: 668, len of whole_edge_set: 1225, len of none edge: 557
# len of edge_set: 873, len of whole_edge_set: 1225, len of none edge: 352
# len of edge_set: 565, len of whole_edge_set: 1225, len of none edge: 660
# len of edge_set: 365, len of whole_edge_set: 1225, len of none edge: 860
# len of edge_set: 356, len of whole_edge_set: 1225, len of none edge: 869
# len of edge_set: 531, len of whole_edge_set: 1225, len of none edge: 694
# len of edge_set: 760, len of whole_edge_set: 1225, len of none edge: 465
# len of edge_set: 388, len of whole_edge_set: 1225, len of none edge: 837
# len of edge_set: 670, len of whole_edge_set: 1225, len of none edge: 555
# len of edge_set: 675, len of whole_edge_set: 1225, len of none edge: 550
# len of edge_set: 648, len of whole_edge_set: 1225, len of none edge: 577
# len of edge_set: 417, len of whole_edge_set: 1225, len of none edge: 808
# len of edge_set: 853, len of whole_edge_set: 1225, len of none edge: 372
# len of edge_set: 877, len of whole_edge_set: 1225, len of none edge: 348
# len of edge_set: 582, len of whole_edge_set: 1225, len of none edge: 643
# len of edge_set: 676, len of whole_edge_set: 1225, len of none edge: 549
# len of edge_set: 514, len of whole_edge_set: 1225, len of none edge: 711
# len of edge_set: 834, len of whole_edge_set: 1225, len of none edge: 391
# len of edge_set: 854, len of whole_edge_set: 1225, len of none edge: 371
# len of edge_set: 832, len of whole_edge_set: 1225, len of none edge: 393
# len of edge_set: 905, len of whole_edge_set: 1225, len of none edge: 320
# len of edge_set: 741, len of whole_edge_set: 1225, len of none edge: 484
# len of edge_set: 599, len of whole_edge_set: 1225, len of none edge: 626
# len of edge_set: 352, len of whole_edge_set: 1225, len of none edge: 873
# len of edge_set: 532, len of whole_edge_set: 1225, len of none edge: 693
# len of edge_set: 310, len of whole_edge_set: 1225, len of none edge: 915
# len of edge_set: 707, len of whole_edge_set: 1225, len of none edge: 518
# len of edge_set: 865, len of whole_edge_set: 1225, len of none edge: 360
# len of edge_set: 414, len of whole_edge_set: 1225, len of none edge: 811
# len of edge_set: 572, len of whole_edge_set: 1225, len of none edge: 653
# len of edge_set: 447, len of whole_edge_set: 1225, len of none edge: 778
# len of edge_set: 347, len of whole_edge_set: 1225, len of none edge: 878
# len of edge_set: 901, len of whole_edge_set: 1225, len of none edge: 324
# len of edge_set: 564, len of whole_edge_set: 1225, len of none edge: 661
# len of edge_set: 496, len of whole_edge_set: 1225, len of none edge: 729
# len of edge_set: 645, len of whole_edge_set: 1225, len of none edge: 580
# len of edge_set: 784, len of whole_edge_set: 1225, len of none edge: 441
# len of edge_set: 815, len of whole_edge_set: 1225, len of none edge: 410
# len of edge_set: 312, len of whole_edge_set: 1225, len of none edge: 913
# len of edge_set: 854, len of whole_edge_set: 1225, len of none edge: 371
# len of edge_set: 730, len of whole_edge_set: 1225, len of none edge: 495
# len of edge_set: 584, len of whole_edge_set: 1225, len of none edge: 641
# len of edge_set: 359, len of whole_edge_set: 1225, len of none edge: 866
# len of edge_set: 321, len of whole_edge_set: 1225, len of none edge: 904
# len of edge_set: 444, len of whole_edge_set: 1225, len of none edge: 781
# len of edge_set: 729, len of whole_edge_set: 1225, len of none edge: 496
# len of edge_set: 586, len of whole_edge_set: 1225, len of none edge: 639
# len of edge_set: 403, len of whole_edge_set: 1225, len of none edge: 822
# len of edge_set: 333, len of whole_edge_set: 1225, len of none edge: 892
# len of edge_set: 612, len of whole_edge_set: 1225, len of none edge: 613
# len of edge_set: 642, len of whole_edge_set: 1225, len of none edge: 583
# len of edge_set: 921, len of whole_edge_set: 1225, len of none edge: 304
# len of edge_set: 872, len of whole_edge_set: 1225, len of none edge: 353
# len of edge_set: 719, len of whole_edge_set: 1225, len of none edge: 506
# len of edge_set: 508, len of whole_edge_set: 1225, len of none edge: 717
# len of edge_set: 584, len of whole_edge_set: 1225, len of none edge: 641
# len of edge_set: 719, len of whole_edge_set: 1225, len of none edge: 506
# len of edge_set: 783, len of whole_edge_set: 1225, len of none edge: 442
# len of edge_set: 801, len of whole_edge_set: 1225, len of none edge: 424
# len of edge_set: 659, len of whole_edge_set: 1225, len of none edge: 566
# len of edge_set: 317, len of whole_edge_set: 1225, len of none edge: 908
# len of edge_set: 779, len of whole_edge_set: 1225, len of none edge: 446
# len of edge_set: 712, len of whole_edge_set: 1225, len of none edge: 513
# len of edge_set: 894, len of whole_edge_set: 1225, len of none edge: 331
# len of edge_set: 434, len of whole_edge_set: 1225, len of none edge: 791
# len of edge_set: 851, len of whole_edge_set: 1225, len of none edge: 374
# len of edge_set: 579, len of whole_edge_set: 1225, len of none edge: 646
# len of edge_set: 905, len of whole_edge_set: 1225, len of none edge: 320
# len of edge_set: 755, len of whole_edge_set: 1225, len of none edge: 470
# len of edge_set: 755, len of whole_edge_set: 1225, len of none edge: 470
# len of edge_set: 737, len of whole_edge_set: 1225, len of none edge: 488
# len of edge_set: 806, len of whole_edge_set: 1225, len of none edge: 419
# len of edge_set: 592, len of whole_edge_set: 1225, len of none edge: 633
# len of edge_set: 443, len of whole_edge_set: 1225, len of none edge: 782
# len of edge_set: 810, len of whole_edge_set: 1225, len of none edge: 415
# len of edge_set: 731, len of whole_edge_set: 1225, len of none edge: 494
# len of edge_set: 733, len of whole_edge_set: 1225, len of none edge: 492
# len of edge_set: 721, len of whole_edge_set: 1225, len of none edge: 504
# len of edge_set: 386, len of whole_edge_set: 1225, len of none edge: 839
# len of edge_set: 713, len of whole_edge_set: 1225, len of none edge: 512
# len of edge_set: 364, len of whole_edge_set: 1225, len of none edge: 861
# len of edge_set: 861, len of whole_edge_set: 1225, len of none edge: 364
# len of edge_set: 529, len of whole_edge_set: 1225, len of none edge: 696
# len of edge_set: 835, len of whole_edge_set: 1225, len of none edge: 390
# len of edge_set: 814, len of whole_edge_set: 1225, len of none edge: 411
# len of edge_set: 821, len of whole_edge_set: 1225, len of none edge: 404
# len of edge_set: 908, len of whole_edge_set: 1225, len of none edge: 317
# len of edge_set: 373, len of whole_edge_set: 1225, len of none edge: 852
# len of edge_set: 671, len of whole_edge_set: 1225, len of none edge: 554
# len of edge_set: 692, len of whole_edge_set: 1225, len of none edge: 533
# len of edge_set: 445, len of whole_edge_set: 1225, len of none edge: 780
# len of edge_set: 437, len of whole_edge_set: 1225, len of none edge: 788
# len of edge_set: 543, len of whole_edge_set: 1225, len of none edge: 682
# len of edge_set: 506, len of whole_edge_set: 1225, len of none edge: 719
# len of edge_set: 509, len of whole_edge_set: 1225, len of none edge: 716
# len of edge_set: 757, len of whole_edge_set: 1225, len of none edge: 468
# len of edge_set: 601, len of whole_edge_set: 1225, len of none edge: 624
# len of edge_set: 831, len of whole_edge_set: 1225, len of none edge: 394
# len of edge_set: 766, len of whole_edge_set: 1225, len of none edge: 459
# len of edge_set: 871, len of whole_edge_set: 1225, len of none edge: 354
# len of edge_set: 694, len of whole_edge_set: 1225, len of none edge: 531
# len of edge_set: 489, len of whole_edge_set: 1225, len of none edge: 736
# len of edge_set: 342, len of whole_edge_set: 1225, len of none edge: 883
# len of edge_set: 624, len of whole_edge_set: 1225, len of none edge: 601
# len of edge_set: 349, len of whole_edge_set: 1225, len of none edge: 876
# len of edge_set: 659, len of whole_edge_set: 1225, len of none edge: 566
# len of edge_set: 646, len of whole_edge_set: 1225, len of none edge: 579
# len of edge_set: 740, len of whole_edge_set: 1225, len of none edge: 485
# len of edge_set: 597, len of whole_edge_set: 1225, len of none edge: 628
# len of edge_set: 783, len of whole_edge_set: 1225, len of none edge: 442
# len of edge_set: 380, len of whole_edge_set: 1225, len of none edge: 845
# len of edge_set: 508, len of whole_edge_set: 1225, len of none edge: 717
# len of edge_set: 397, len of whole_edge_set: 1225, len of none edge: 828
# len of edge_set: 507, len of whole_edge_set: 1225, len of none edge: 718
# len of edge_set: 687, len of whole_edge_set: 1225, len of none edge: 538
# validation label presreved: 82
# len of edge_set: 853, len of whole_edge_set: 1225, len of none edge: 372
# add_num: 100, delete_num: 0
# len of edge_set: 750, len of whole_edge_set: 1225, len of none edge: 475
# add_num: 100, delete_num: 0
# len of edge_set: 818, len of whole_edge_set: 1225, len of none edge: 407
# add_num: 100, delete_num: 0
# len of edge_set: 722, len of whole_edge_set: 1225, len of none edge: 503
# add_num: 100, delete_num: 0
# len of edge_set: 331, len of whole_edge_set: 1225, len of none edge: 894
# add_num: 100, delete_num: 0
# len of edge_set: 913, len of whole_edge_set: 1225, len of none edge: 312
# add_num: 100, delete_num: 0
# len of edge_set: 534, len of whole_edge_set: 1225, len of none edge: 691
# add_num: 100, delete_num: 0
# len of edge_set: 432, len of whole_edge_set: 1225, len of none edge: 793
# add_num: 100, delete_num: 0
# len of edge_set: 576, len of whole_edge_set: 1225, len of none edge: 649
# add_num: 100, delete_num: 0
# len of edge_set: 443, len of whole_edge_set: 1225, len of none edge: 782
# add_num: 100, delete_num: 0
# len of edge_set: 781, len of whole_edge_set: 1225, len of none edge: 444
# add_num: 100, delete_num: 0
# len of edge_set: 801, len of whole_edge_set: 1225, len of none edge: 424
# add_num: 100, delete_num: 0
# len of edge_set: 491, len of whole_edge_set: 1225, len of none edge: 734
# add_num: 100, delete_num: 0
# len of edge_set: 735, len of whole_edge_set: 1225, len of none edge: 490
# add_num: 100, delete_num: 0
# len of edge_set: 571, len of whole_edge_set: 1225, len of none edge: 654
# add_num: 100, delete_num: 0
# len of edge_set: 715, len of whole_edge_set: 1225, len of none edge: 510
# add_num: 100, delete_num: 0
# len of edge_set: 784, len of whole_edge_set: 1225, len of none edge: 441
# add_num: 100, delete_num: 0
# len of edge_set: 476, len of whole_edge_set: 1225, len of none edge: 749
# add_num: 100, delete_num: 0
# len of edge_set: 524, len of whole_edge_set: 1225, len of none edge: 701
# add_num: 100, delete_num: 0
# len of edge_set: 799, len of whole_edge_set: 1225, len of none edge: 426
# add_num: 100, delete_num: 0
# len of edge_set: 433, len of whole_edge_set: 1225, len of none edge: 792
# add_num: 100, delete_num: 0
# len of edge_set: 816, len of whole_edge_set: 1225, len of none edge: 409
# add_num: 100, delete_num: 0
# len of edge_set: 703, len of whole_edge_set: 1225, len of none edge: 522
# add_num: 100, delete_num: 0
# len of edge_set: 428, len of whole_edge_set: 1225, len of none edge: 797
# add_num: 100, delete_num: 0
# len of edge_set: 402, len of whole_edge_set: 1225, len of none edge: 823
# add_num: 100, delete_num: 0
# len of edge_set: 415, len of whole_edge_set: 1225, len of none edge: 810
# add_num: 100, delete_num: 0
# len of edge_set: 895, len of whole_edge_set: 1225, len of none edge: 330
# add_num: 100, delete_num: 0
# len of edge_set: 890, len of whole_edge_set: 1225, len of none edge: 335
# add_num: 100, delete_num: 0
# len of edge_set: 402, len of whole_edge_set: 1225, len of none edge: 823
# add_num: 100, delete_num: 0
# len of edge_set: 697, len of whole_edge_set: 1225, len of none edge: 528
# add_num: 100, delete_num: 0
# len of edge_set: 558, len of whole_edge_set: 1225, len of none edge: 667
# add_num: 100, delete_num: 0
# len of edge_set: 740, len of whole_edge_set: 1225, len of none edge: 485
# add_num: 100, delete_num: 0
# len of edge_set: 379, len of whole_edge_set: 1225, len of none edge: 846
# add_num: 100, delete_num: 0
# len of edge_set: 370, len of whole_edge_set: 1225, len of none edge: 855
# add_num: 100, delete_num: 0
# len of edge_set: 817, len of whole_edge_set: 1225, len of none edge: 408
# add_num: 100, delete_num: 0
# len of edge_set: 426, len of whole_edge_set: 1225, len of none edge: 799
# add_num: 100, delete_num: 0
# len of edge_set: 763, len of whole_edge_set: 1225, len of none edge: 462
# add_num: 100, delete_num: 0
# len of edge_set: 467, len of whole_edge_set: 1225, len of none edge: 758
# add_num: 100, delete_num: 0
# len of edge_set: 494, len of whole_edge_set: 1225, len of none edge: 731
# add_num: 100, delete_num: 0
# len of edge_set: 481, len of whole_edge_set: 1225, len of none edge: 744
# add_num: 100, delete_num: 0
# len of edge_set: 668, len of whole_edge_set: 1225, len of none edge: 557
# add_num: 100, delete_num: 0
# len of edge_set: 704, len of whole_edge_set: 1225, len of none edge: 521
# add_num: 100, delete_num: 0
# len of edge_set: 653, len of whole_edge_set: 1225, len of none edge: 572
# add_num: 100, delete_num: 0
# len of edge_set: 701, len of whole_edge_set: 1225, len of none edge: 524
# add_num: 100, delete_num: 0
# len of edge_set: 630, len of whole_edge_set: 1225, len of none edge: 595
# add_num: 100, delete_num: 0
# len of edge_set: 598, len of whole_edge_set: 1225, len of none edge: 627
# add_num: 100, delete_num: 0
# len of edge_set: 326, len of whole_edge_set: 1225, len of none edge: 899
# add_num: 100, delete_num: 0
# len of edge_set: 456, len of whole_edge_set: 1225, len of none edge: 769
# add_num: 100, delete_num: 0
# len of edge_set: 453, len of whole_edge_set: 1225, len of none edge: 772
# add_num: 100, delete_num: 0
# len of edge_set: 467, len of whole_edge_set: 1225, len of none edge: 758
# add_num: 100, delete_num: 0
# label presreved: 19
# Epoch: 4, Loss: 2.0968241691589355, similarity_loss: 0.6756036877632141, difference_loss: 0.74
